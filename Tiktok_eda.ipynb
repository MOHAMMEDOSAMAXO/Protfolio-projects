# %%
# Import packages for data manipulation
import pandas as pd 
import numpy as np

# Import packages for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# we load the data

# %%
data=pd.read_csv("Data/tiktok_dataset.csv")

# %%
data.head()
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %%
data.shape
# Out:
# (19382, 12)

# %%
data.isna().any(axis=1).sum()
# Out:
# 298

# %%
data.dropna(axis=0,inplace=True)
data.isna().any(axis=1).sum()
# Out:
# 0

# %% [markdown]
# After the we cleaned our data now we can perform some data visualizations to better undersand our data

# %%
# Create a boxplot to visualize distribution of `video_duration_sec`
plt.figure(figsize=(10,6))
sns.boxplot(data=data, x='video_duration_sec')
# Out:
# <Axes: xlabel='video_duration_sec'>

# %%
# Create a histogram
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='video_duration_sec',bins=range(0,61,5))
plt.title("Distribution of Video duration")
plt.xlabel("Seconds")
# Out:
# Text(0.5, 0, 'Seconds')

# %% [markdown]
# All videos are 5-60 seconds in length, and the distribution is uniform

# %%
# Create a boxplot to visualize distribution of `video_view_count`
plt.figure(figsize=(10,6))
sns.boxplot(data=data,x='video_view_count')
plt.title("Distribution of Video View count")
plt.xlabel("Views count")
# Out:
# Text(0.5, 0, 'Views count')

# %%
# Create a histogram
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='video_view_count')
plt.title("Distribution of Video View count")
plt.xlabel("Views count")
# Out:
# Text(0.5, 0, 'Views count')

# %% [markdown]
# as we can see here the distribution of the video view count is very uneven most of the views are < 100,000 views

# %%
# Create a boxplot to visualize distribution of `video_like_count`
plt.figure(figsize=(10,6))
sns.boxplot(data=data,x='video_like_count')
# Out:
# <Axes: xlabel='video_like_count'>

# %%
# Create a histogram
#plt.figure(figsize=(10,6))
sns.histplot(data=data,x='video_like_count')
plt.title("Distribution of Video like count")
plt.xlabel("likes count")
# Out:
# Text(0.5, 0, 'likes count')

# %% [markdown]
# from the box plot we see that there are some outliers, and from the histplot we can observe that there is a skew present in the data

# %%
# Create a boxplot to visualize distribution of `video_comment_count`
plt.figure(figsize=(10,6))
sns.boxplot(data=data,x='video_comment_count')
# Out:
# <Axes: xlabel='video_comment_count'>

# %%
# Create a histogram
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='video_comment_count')
plt.title("Distribution of Video comment count")
plt.xlabel("comment count")
# Out:
# Text(0.5, 0, 'comment count')

# %% [markdown]
# Again same problem with the video comment count, we see the outliers present

# %%
# Create a boxplot to visualize distribution of `video_share_count`
plt.figure(figsize=(10,6))
sns.boxplot(data=data,x='video_share_count')
# Out:
# <Axes: xlabel='video_share_count'>

# %%
# Create a histogram
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='video_share_count')
plt.title("Distribution of Video share count")
plt.xlabel("share count")
# Out:
# Text(0.5, 0, 'share count')

# %% [markdown]
# Again same problem with the video comment count, we see the outliers present

# %%
# Create a boxplot to visualize distribution of `video_download_count`
plt.figure(figsize=(10,6))
sns.boxplot(data=data,x='video_download_count')
# Out:
# <Axes: xlabel='video_download_count'>

# %%
# Create a histogram
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='video_download_count')
plt.title("Distribution of Video Download count")
plt.xlabel("Download count")
# Out:
# Text(0.5, 0, 'Download count')

# %% [markdown]
# Again same problem with the video comment count, we see the outliers present

# %% [markdown]
# Now, create a histogram with four bars: one for each combination of claim status and verification status.

# %%
data['verified_status'].unique()
# Out:
# array(['not verified', 'verified'], dtype=object)

# %%
# Create a histogram
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='claim_status',hue='verified_status',multiple='dodge',shrink=0.9)
plt.xlabel('Claim status')
# Out:
# Text(0.5, 0, 'Claim status')

# %% [markdown]
# #### **Claim status by author ban status**

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='claim_status',hue='author_ban_status',hue_order=['active','under review','banned'],multiple='dodge',shrink=0.9)
plt.xlabel('Claim status')
# Out:
# Text(0.5, 0, 'Claim status')

# %% [markdown]
# we see that for both claims the active status is majority, however the opinion active users are far more than the calim active users

# %%
ban_status_coumt=data.groupby(['author_ban_status']).median(numeric_only=True).reset_index()
fig=plt.figure(figsize=(10,6))
sns.barplot(data=ban_status_coumt, x='author_ban_status',y='video_view_count')
plt.title("Median view counts by ban status")
# Out:
# Text(0.5, 1.0, 'Median view counts by ban status')

# %%
data.groupby(['claim_status'])['video_view_count'].median()
# Out:
# claim_status
# claim      501555.0
# opinion      4953.0
# Name: video_view_count, dtype: float64

# %% [markdown]
# now we can deal with the outliers

# %%
count_cols = ['video_view_count',
'video_like_count',
'video_share_count',
'video_download_count',
'video_comment_count',
]
for column in count_cols:
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    median = data[column].median()
    outlier_threshold = median + 1.5*iqr
# Count the number of values that exceed the outlier threshold
    outlier_count = (data[column] > outlier_threshold).sum()
    print(f'Number of outliers, {column}:', outlier_count)
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %%
sns.scatterplot(x=data["video_view_count"], y=data["video_like_count"],
hue=data["claim_status"], s=10, alpha=.3)
plt.show()

# %%
# Check for and handle outliers for video_like_count
prec75=data['video_like_count'].quantile(0.75)
prec25=data['video_like_count'].quantile(0.25)
iqr = prec75 - prec25
upper_limit= prec75 + 1.5*iqr

data.loc[data['video_like_count']>upper_limit,'video_like_count']=upper_limit

# Check class balance for video_comment_count
prec75=data['video_comment_count'].quantile(0.75)
prec25=data['video_comment_count'].quantile(0.25)
iqr = prec75 - prec25
upper_limit= prec75 + 1.5*iqr

data.loc[data['video_comment_count']>upper_limit,'video_comment_count']=upper_limit


# Check class balance for video_share_count
prec75=data['video_share_count'].quantile(0.75)
prec25=data['video_share_count'].quantile(0.25)
iqr = prec75 - prec25
upper_limit= prec75 + 1.5*iqr

data.loc[data['video_share_count']>upper_limit,'video_share_count']=upper_limit


# Check class balance for video_download_count
prec75=data['video_download_count'].quantile(0.75)
prec25=data['video_download_count'].quantile(0.25)
iqr = prec75 - prec25
upper_limit= prec75 + 1.5*iqr

data.loc[data['video_download_count']>upper_limit,'video_download_count']=upper_limit


# Check class balance for video_view_count
prec75=data['video_view_count'].quantile(0.75)
prec25=data['video_view_count'].quantile(0.25)
iqr = prec75 - prec25
upper_limit= prec75 + 1.5*iqr

data.loc[data['video_view_count']>upper_limit,'video_view_count']=upper_limit

# %% [markdown]
# lets run the a hitsplot and boxplot again to see the outliers

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='video_download_count')
plt.title("Distribution of Video Download count")
plt.xlabel("Download count")
# Out:
# Text(0.5, 0, 'Download count')

# %%
# Create a boxplot to visualize distribution of `video_download_count`
plt.figure(figsize=(10,6))
sns.boxplot(data=data,x='video_download_count')
# Out:
# <Axes: xlabel='video_download_count'>

# %% [markdown]
# as we can see there is no outliers in the videp_download_count column anymore
